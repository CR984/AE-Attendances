# %% [markdown]
# # API Project

# %% [markdown]
# https://www.opendata.nhs.scot/dataset/weekly-accident-and-emergency-activity-and-waiting-times/resource/a5f7ca94-c810-41b5-a7c9-25c18d43e5a4

# %% [markdown]
# ### Import Libraries

# %%
import requests # For sending the API request
import json
from sqlalchemy import create_engine  # For connecting to a PostgreSQL database (or other databases)
import os
import pandas as pd

# %% [markdown]
# ### Make the API request

# %%
# API URL
url = "https://www.opendata.nhs.scot/api/3/action/datastore_search"

# Parameters
params = {
    "resource_id": "a5f7ca94-c810-41b5-a7c9-25c18d43e5a4",
    "limit": 1300,
    "filters": json.dumps({"TreatmentLocation": "S308H"})
}

# Send the request
response = requests.get(url, params=params)

# %% [markdown]
# ### Interpret the result

# %%
if response.status_code == 200:
    print(f"Request was a success! Status code: {response.status_code}")
else:
    print(f"Error: {response.status_code}")
# Out:
# Request was a success! Status code: 200

# %% [markdown]
# ### Print the records

# %%
if response.status_code == 200:
    data = response.json()
    records = data.get("result", {}).get("records", [])  # Extract the records

# %% [markdown]
# ### Add records to a data frame

# %%
import pandas as pd

# Convert records to a DataFrame
df = pd.DataFrame(records)

# Show the first few rows
df.tail()
# Out:
#         _id  WeekEndingDate    Country        HBT TreatmentLocation  \
# 1264  40846        20260412  S92000003  S08000024             S308H
# 1265  40847        20260412  S92000003  S08000024             S308H
# 1266  40933        20260419  S92000003  S08000024             S308H
# 1267  40934        20260419  S92000003  S08000024             S308H
# 1268  40935        20260419  S92000003  S08000024             S308H
#
#      DepartmentType AttendanceCategory  NumberOfAttendancesEpisode  \
# 1264         Type 1          Unplanned                        1137
# 1265         Type 1                All                        1314
# 1266         Type 1        New planned                         207
# 1267         Type 1          Unplanned                        1196
# 1268         Type 1                All                        1403
#
#       NumberWithin4HoursEpisode  NumberOver4HoursEpisode  \
# 1264                        722                      415
# 1265                        899                      415
# 1266                        207                        0
# 1267                        673                      523
# 1268                        880                      523
#
#       PercentageWithin4HoursEpisode  NumberOver8HoursEpisode  \
# 1264                           63.5                      115
# 1265                           68.4                      115
# 1266                          100.0                        0
# 1267                           56.3                      153
# 1268                           62.7                      153
#
#       PercentageOver8HoursEpisode  NumberOver12HoursEpisode  \
# 1264                         10.1                        61
# 1265                          8.8                        61
# 1266                          0.0                         0
# 1267                         12.8                        81
# 1268                         10.9                        81
#
#       PercentageOver12HoursEpisode
# 1264                           5.4
# 1265                           4.6
# 1266                           0.0
# 1267                           6.8
# 1268                           5.8

# %% [markdown]
# # Transformation

# %%
df.columns = df.columns.str.lower()
df = df.drop(columns = ["country", "hbt"])
df.tail()
# Out:
#         _id  weekendingdate treatmentlocation departmenttype  \
# 1264  40846        20260412             S308H         Type 1
# 1265  40847        20260412             S308H         Type 1
# 1266  40933        20260419             S308H         Type 1
# 1267  40934        20260419             S308H         Type 1
# 1268  40935        20260419             S308H         Type 1
#
#      attendancecategory  numberofattendancesepisode  \
# 1264          Unplanned                        1137
# 1265                All                        1314
# 1266        New planned                         207
# 1267          Unplanned                        1196
# 1268                All                        1403
#
#       numberwithin4hoursepisode  numberover4hoursepisode  \
# 1264                        722                      415
# 1265                        899                      415
# 1266                        207                        0
# 1267                        673                      523
# 1268                        880                      523
#
#       percentagewithin4hoursepisode  numberover8hoursepisode  \
# 1264                           63.5                      115
# 1265                           68.4                      115
# 1266                          100.0                        0
# 1267                           56.3                      153
# 1268                           62.7                      153
#
#       percentageover8hoursepisode  numberover12hoursepisode  \
# 1264                         10.1                        61
# 1265                          8.8                        61
# 1266                          0.0                         0
# 1267                         12.8                        81
# 1268                         10.9                        81
#
#       percentageover12hoursepisode
# 1264                           5.4
# 1265                           4.6
# 1266                           0.0
# 1267                           6.8
# 1268                           5.8

# %% [markdown]
# # Add data to the database

# %% [markdown]
# ### Create connection to the database

# %%
# Create a connection to the database
db_user = "postgres"
db_password = os.environ.get("DB_PASSWORD")
db_host = "localhost"
db_port = "5432"
db_name = "A&E Attendances"

engine = create_engine(f"postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}")

with engine.connect() as conn:
    print("Connected to PostgreSQL successfully!")
# Out:
# Connected to PostgreSQL successfully!

# %% [markdown]
# ### Load data into the database

# %%
existing_ids = pd.read_sql("SELECT _id FROM a_and_e_attendances", con=engine)['_id']
new_data = df[~df['_id'].isin(existing_ids)]

if not new_data.empty:
    new_data.to_sql("a_and_e_attendances", con=engine, if_exists="append", index=False)
    print(f"{len(new_data)} row(s) have been added to the database.")
else:
    print("Data already present within table.")

print("All data processed successfully!")
# Out:
# Data already present within table.
# All data processed successfully!
